# %% [markdown]
# # Linear Regresion

# %% [markdown]
# ### BY: Harsh Kumar Dubey

# %% [markdown]
# #### Import required libraries

# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Load data

# %%
url = "http://bit.ly/w-data"
df = pd.read_csv(url)

df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# #### Plot the graph

# %%
sorted_df = df.sort_values('Hours')
plt.figure()
plt.plot(sorted_df['Hours'], sorted_df['Scores'])
plt.scatter(sorted_df['Hours'], sorted_df['Scores'])
plt.xticks(range(1,10))
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### Train Linear regression Model

# %%
x = df['Hours'].values

y = df.iloc[:, 1].values
x = x.reshape(-1,1)

X_train, X_test, Y_train, Y_test = train_test_split(x, y, random_state=0)

# %%
 
model = LinearRegression()  
model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
line = model.coef_*x+model.intercept_

# Plotting for the test data
plt.figure()
plt.scatter(x, y)
plt.plot(x, line)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
y_predict = model.predict(X_test)

# %% [markdown]
# ## Actual Vs Predicted  Scores

# %%
result = pd.DataFrame({'Actual': Y_test, 'Predicted': y_predict})  
result
# Out:
#    Actual  Predicted
# 0      20  16.844722
# 1      27  33.745575
# 2      69  75.500624
# 3      30  26.786400
# 4      62  60.588106
# 5      35  39.710582
# 6      24  20.821393

# %% [markdown]
# #### Predicte score for hours given

# %%
hours = [[9.25]]
own_pred = model.predict(hours)
print("No of Hours = {}".format(hours[0][0]))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.89272889341652
